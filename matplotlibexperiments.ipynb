# %% [markdown]
# matplotlib experiments based on : https://matplotlib.org/cheatsheets/_images/handout-beginner.png

# %% [markdown]
# Initialiser

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# prepare

# %%
X=np.linspace(0,4*np.pi,100)

# %%
Y=np.cos(X)

# %% [markdown]
# show  from a "numpy-array"

# %%
plt.plot(X,Y)

# %%
fig,ax = plt.subplots()   #  ??

# %%
ax.plot(X,Y)   #  ??

# %%
plt.show()    #  ??

# %%
Z=np.random.uniform(0,1,(8,8))

# %%
plt.plot(Z)
# Out:
# [<matplotlib.lines.Line2D at 0x143a02e1290>,
#  <matplotlib.lines.Line2D at 0x143a02cec10>,
#  <matplotlib.lines.Line2D at 0x143a02e1950>,
#  <matplotlib.lines.Line2D at 0x143a02e1d50>,
#  <matplotlib.lines.Line2D at 0x143a02e2110>,
#  <matplotlib.lines.Line2D at 0x143a02e2610>,
#  <matplotlib.lines.Line2D at 0x143a02e2b10>,
#  <matplotlib.lines.Line2D at 0x143a02e2f90>]

# %%
ax.imshow(Z)

# %%
np.random.seed(19680801)


N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (30 * np.random.rand(N))**2  # 0 to 15 point radii

plt.scatter(x, y, s=area, c=colors, alpha=0.59)
plt.show()
